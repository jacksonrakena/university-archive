# %%
# This file plots some data about Maori fruit farming from a CSV file

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mf=pd.read_csv("maorifarm.csv")
mf
# Out:
#    Year  Kiwifruit  Avocados  Wine_grapes  Onions  Squash
# 0  2007     311.44     39.80         75.9   212.0     0.4
# 1  2009     344.95     39.00         83.0   230.0    50.1
# 2  2011     349.38     49.90        207.5   290.0   150.1
# 3  2012     347.18    114.61        298.7   291.0   210.1
# 4  2014     314.27     78.90        408.0   317.6   224.1

# %%
mf.describe()
# Out:
#               Year   Kiwifruit    Avocados  Wine_grapes    Onions      Squash
# count     5.000000    5.000000    5.000000     5.000000    5.0000    5.000000
# mean   2010.600000  333.444000   64.442000   214.620000  268.1200  126.960000
# std       2.701851   18.886769   32.372269   142.375409   44.8695   98.499736
# min    2007.000000  311.440000   39.000000    75.900000  212.0000    0.400000
# 25%    2009.000000  314.270000   39.800000    83.000000  230.0000   50.100000
# 50%    2011.000000  344.950000   49.900000   207.500000  290.0000  150.100000
# 75%    2012.000000  347.180000   78.900000   298.700000  291.0000  210.100000
# max    2014.000000  349.380000  114.610000   408.000000  317.6000  224.100000

# %%
plt.plot(mf['Year'], mf['Kiwifruit'])
plt.show()

# %%
mf.plot.bar(x='Year')
plt.show()

# %%
mf.plot(x='Year')
plt.show()

# %%
xf = mf[mf['Year']==2012]
yf= xf.iloc[0,1:]
yf
# Out:
# Kiwifruit      347.18
# Avocados       114.61
# Wine_grapes    298.70
# Onions         291.00
# Squash         210.10
# Name: 3, dtype: float64

# %%
yf.plot.bar()
plt.show()

# %%
plt.pie(yf)
plt.show()

# %%
yf.plot(kind='pie')
plt.show()

# %%
mf.plot(kind='scatter',x='Year', y='Kiwifruit')
# Out:
# <Axes: xlabel='Year', ylabel='Kiwifruit'>

# %%
plt.show()

# %%
yf
# Out:
# Kiwifruit      347.18
# Avocados       114.61
# Wine_grapes    298.70
# Onions         291.00
# Squash         210.10
# Name: 3, dtype: float64

# %%
print(yf.values)
# Out:
# [347.18 114.61 298.7  291.   210.1 ]

# %%
plt.scatter(x=range(len(yf.values)), y = yf.values, s = yf.values)
plt.show()
